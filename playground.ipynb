# %%
from torrentleech import TorrentLeechSearcher

# %%
t = TorrentLeechSearcher()

# %%
t.login('OmerBA', "Su0q1nrrOESa5ys2f&VmX1Qs53g7x6Lu")
# Out:
# [2015-04-24 12:22:00.279000] INFO: torrentleech: Logged on to Torrentleech with session_id t3s4seera7j9u8ognps34cn4e7

# %%
r = t.query_tracker("Windows 8.1")
# Out:
# [2015-04-24 12:22:36.421000] DEBUG: torrentleech: Found 100 results on page
# [2015-04-24 12:22:36.422000] DEBUG: torrentleech: working on: Windows 8 1 8in1 x64 en-US Apr2015
# [2015-04-24 12:22:36.424000] DEBUG: torrentleech: working on: TL-0day APR11 APR12 APR13-2015
# [2015-04-24 12:22:36.425000] DEBUG: torrentleech: working on: TL-0day MAR05-2015
# [2015-04-24 12:22:36.428000] DEBUG: torrentleech: working on: TL-0day MAR03-2015
# [2015-04-24 12:22:36.429000] DEBUG: torrentleech: working on: EBOOKS WEEK09 2015-TL
# [2015-04-24 12:22:36.432000] DEBUG: torrentleech: working on: LYNDA UP AND RUNNING WITH WINDOWS 8 1 PHONES TUTORIAL-kEISO
# [2015-04-24 12:22:36.436000] DEBUG: torrentleech: working on: Windows 8 1 8in1 x86 en-US Feb2015
# [2015-04-24 12:22:36.440000] DEBUG: torrentleech: working on: Windows 8 1 8in1 x64 en-US Feb2015
# [2015-04-24 12:22:36.445000] DEBUG: torrentleech: working on: TL-0day FEB11-2015
# [2015-04-24 12:22:36.448000] DEBUG: torrentleech: working on: TL-0day JAN31-2015
# [2015-04-24 12:22:36.450000] DEBUG: torrentleech: working on: Windows SuperAIO v6 110-in-1 en-US DaRT7-8 1 - murphy78
# [2015-04-24 12:22:36.460000] DEBUG: torrentleech: working on: Windows 8 1 AIO 54in1 with Update x86 en-US Dec2014 FINAL v2
# [2015-04-24 12:22:36.465000] DEBUG: torrentleech: working on: Windows 8 1 AIO 54in1 with Update x64 en-US Dec2014 FINAL v2
# [2015-04-24 12:22:36.469000] DEBUG: torrentleech: working on: Windows 8 1 8in1 x86 en-US Jan2015
# [2015-04-24 12:22:36.471000] DEBUG: torrentleech: working on: Windows 8 1 8in1 x64 en-US Jan2015
# [2015-04-24 12:22:36.474000] DEBUG: torrentleech: working on: TL-0day JAN21-2015
# [2015-04-24 12:22:36.486000] DEBUG: torrentleech: working on: EBOOKS WEEK02 2015-TL
# [2015-04-24 12:22:36.493000] DEBUG: torrentleech: working on: Windows 8 1 AIO 54in1 with Update x86 en-US Dec2014
# [2015-04-24 12:22:36.497000] DEBUG: torrentleech: working on: Windows 8 1 AIO 54in1 with Update x64 en-US Dec2014
# [2015-04-24 12:22:36.501000] DEBUG: torrentleech: working on: TL-0day DEC24-2014
# [2015-04-24 12:22:36.522000] DEBUG: torrentleech: working on: TL-0day DEC22-2014
# [2015-04-24 12:22:36.526000] DEBUG: torrentleech: working on: TL-0day NOV23-2014
# [2015-04-24 12:22:36.542000] DEBUG: torrentleech: working on: TL-0day NOV22-2014
# [2015-04-24 12:22:36.547000] DEBUG: torrentleech: working on: Video2Brain Hyper V auf Windows 8 1 Grundlagen GERMAN-LiQUiDWARE
# [2015-04-24 12:22:36.551000] DEBUG: torrentleech: working on: TL-0day NOV06-2014
# [2015-04-24 12:22:36.554000] DEBUG: torrentleech: working on: Windows 8 1 AIO 48in1 with Update x86 en-US Oct2014
# [2015-04-24 12:22:36.558000] DEBUG: torrentleech: working on: Windows 8 1 AIO 48in1 with Update x64 en-US Oct2014
# [2015-04-24 12:22:36.571000] DEBUG: torrentleech: working on: TL-0day SEP12-2014
# [2015-04-24 12:22:36.576000] DEBUG: torrentleech: working on: Windows 8 1 Dark V11 6
# [2015-04-24 12:22:36.581000] DEBUG: torrentleech: working on: Windows 8 1 AIO 24in1 with Update x86 en-US Jul2014
# [2015-04-24 12:22:36.583000] DEBUG: torrentleech: working on: Windows 8 1 AIO 24in1 with Update x64 en-US Jul2014
# [2015-04-24 12:22:36.585000] DEBUG: torrentleech: working on: LYNDA WINDOWS 8 1 TIPS AND TRICKS TUTORIAL-kEISO
# [2015-04-24 12:22:36.587000] DEBUG: torrentleech: working on: CBT NUGGETS MICROSOFT MCSA WINDOWS 8 1 70 687 CONFIGURING WINDOWS 8 1 TUTORIAL-kEISO
# [2015-04-24 12:22:36.589000] DEBUG: torrentleech: working on: Microsoft Windows Embedded 8 1 Industry Enterprise x64 GERMAN-NEWiSO
# [2015-04-24 12:22:36.591000] DEBUG: torrentleech: working on: Microsoft Windows Embedded 8 1 Industry Enterprise x64-NEWiSO
# [2015-04-24 12:22:36.593000] DEBUG: torrentleech: working on: Microsoft Windows Embedded 8 1 Industry Enterprise x86 GERMAN-NEWiSO
# [2015-04-24 12:22:36.595000] DEBUG: torrentleech: working on: Microsoft Windows Embedded 8 1 Industry Enterprise x86-NEWiSO
# [2015-04-24 12:22:36.597000] DEBUG: torrentleech: working on: Microsoft Windows Embedded 8 1 Industry Pro x64 GERMAN-NEWiSO
# [2015-04-24 12:22:36.599000] DEBUG: torrentleech: working on: Microsoft Windows Embedded 8 1 Industry Pro x64-NEWiSO
# [2015-04-24 12:22:36.611000] DEBUG: torrentleech: working on: Microsoft Windows Embedded 8 1 Industry Pro x86 GERMAN-NEWiSO
# [2015-04-24 12:22:36.615000] DEBUG: torrentleech: working on: Microsoft Windows Embedded 8 1 Industry Pro x86-NEWiSO
# [2015-04-24 12:22:36.618000] DEBUG: torrentleech: working on: EBOOKS WEEK25 2014-TL
# [2015-04-24 12:22:36.623000] DEBUG: torrentleech: working on: VTC Complete pack
# [2015-04-24 12:22:36.625000] DEBUG: torrentleech: working on: Windows 8 1 AIO 24in1 with Update x86 en-US Jun2014
# [2015-04-24 12:22:36.627000] DEBUG: torrentleech: working on: Windows 8 1 AIO 24in1 with Update x64 en-US Jun2014
# [2015-04-24 12:22:36.630000] DEBUG: torrentleech: working on: Windows 8 1 Enterprise with Update (x64) - MultiLang
# [2015-04-24 12:22:36.632000] DEBUG: torrentleech: working on: Windows 8 1 with Update & Crack x86 pt-BR Mar2014 MSDN
# [2015-04-24 12:22:36.634000] DEBUG: torrentleech: working on: Windows 8 1 with Updates & Crack x64 pt-BR Mar2014 MSDN
# [2015-04-24 12:22:36.636000] DEBUG: torrentleech: working on: Extreme Android Pack-TL
# [2015-04-24 12:22:36.639000] DEBUG: torrentleech: working on: Ebooks Pack-TL
# [2015-04-24 12:22:36.642000] DEBUG: torrentleech: working on: TL-0day JUN01-2014
# [2015-04-24 12:22:36.644000] DEBUG: torrentleech: working on: EBOOKS WEEK22 2014-TL
# [2015-04-24 12:22:36.646000] DEBUG: torrentleech: working on: Windows 8 1 AIO 20in1 with Update x64 en-US May2014
# [2015-04-24 12:22:36.649000] DEBUG: torrentleech: working on: Windows 8 1 AIO 20in1 with Update x86 en-US May2014
# [2015-04-24 12:22:36.654000] DEBUG: torrentleech: working on: Video2Brain Windows 8 1 fuer Profis UPDATE 05 2014 GERMAN-EMERGE
# [2015-04-24 12:22:36.662000] DEBUG: torrentleech: working on: TL-0day MAY23-2014
# [2015-04-24 12:22:36.665000] DEBUG: torrentleech: working on: TL-0day MAY21-2014
# [2015-04-24 12:22:36.669000] DEBUG: torrentleech: working on: Video2Brain Windows v8 1 Tipps Tricks Troubleshooting Update04 2014 GERMAN-SHooTERS
# [2015-04-24 12:22:36.673000] DEBUG: torrentleech: working on: TL-0day MAY19-2014
# [2015-04-24 12:22:36.676000] DEBUG: torrentleech: working on: EBOOKS WEEK20 2014-TL
# [2015-04-24 12:22:36.678000] DEBUG: torrentleech: working on: PLURALSIGHT DEPLOYING WINDOWS 8 1 AND WINDOWS SERVER 2012 R2 USING MDT 2013 TUTORIAL-kEISO
# [2015-04-24 12:22:36.680000] DEBUG: torrentleech: working on: Telerik 2014 Q1 Pack-TL
# [2015-04-24 12:22:36.683000] DEBUG: torrentleech: working on: EBOOKS WEEK16 2014-TL
# [2015-04-24 12:22:36.685000] DEBUG: torrentleech: working on: Windows 8 1 AIO 20in1 with Update x64 en-US April 2014 v2
# [2015-04-24 12:22:36.687000] DEBUG: torrentleech: working on: Windows 8 1 AIO 20in1 with Update x86 en-US April 2014 v2
# [2015-04-24 12:22:36.689000] DEBUG: torrentleech: working on: LYNDA WINDOWS 8 1 UPDATE 1 FIRST LOOK TUTORIAL-kEISO
# [2015-04-24 12:22:36.692000] DEBUG: torrentleech: working on: EBOOKS WEEK14 2014-TL
# [2015-04-24 12:22:36.694000] DEBUG: torrentleech: working on: Windows Embedded 8 1 Industry Pro with Update (x64) - DVD (English)
# [2015-04-24 12:22:36.696000] DEBUG: torrentleech: working on: Windows Embedded 8 1 Industry Pro with Update (x86) - DVD (English)
# [2015-04-24 12:22:36.698000] DEBUG: torrentleech: working on: Windows Embedded 8 1 Industry Enterprise with Update (x64) - DVD (English)
# [2015-04-24 12:22:36.701000] DEBUG: torrentleech: working on: Windows Embedded 8 1 Industry Enterprise with Update (x86) - DVD (English)
# [2015-04-24 12:22:36.703000] DEBUG: torrentleech: working on: Windows 8 1 Professional VL with Update (x64) - DVD (English)
# [2015-04-24 12:22:36.705000] DEBUG: torrentleech: working on: Windows 8 1 Professional VL with Update (x86) - DVD (English)
# [2015-04-24 12:22:36.708000] DEBUG: torrentleech: working on: Windows 8 1 Enterprise N with Update (x64) - DVD (English)
# [2015-04-24 12:22:36.710000] DEBUG: torrentleech: working on: Windows 8 1 Enterprise N with Update (x86) - DVD (English)
# [2015-04-24 12:22:36.712000] DEBUG: torrentleech: working on: Windows 8 1 N with Update (multiple editions) (x64) - DVD (English)
# [2015-04-24 12:22:36.714000] DEBUG: torrentleech: working on: Windows 8 1 N with Update (multiple editions) (x86) - DVD (English)
# [2015-04-24 12:22:36.716000] DEBUG: torrentleech: working on: Windows 8 1 Enterprise with Update (x64) - DVD (English)
# [2015-04-24 12:22:36.718000] DEBUG: torrentleech: working on: Windows 8 1 Enterprise with Update (x86) - DVD (English)
# [2015-04-24 12:22:36.720000] DEBUG: torrentleech: working on: Windows 8 1 with Update (multiple editions) (x64) - DVD (English)
# [2015-04-24 12:22:36.723000] DEBUG: torrentleech: working on: Windows 8 1 with Update (multiple editions) (x86) - DVD (English)
# [2015-04-24 12:22:36.728000] DEBUG: torrentleech: working on: Windows 8 1 AIO S14 x86 en-US DaRT 8 1 Pre-Activated Mar2014
# [2015-04-24 12:22:36.734000] DEBUG: torrentleech: working on: Windows 8 1 AIO S14 x64 en-US DaRT 8 1 Pre-Activated Mar2014
# [2015-04-24 12:22:36.738000] DEBUG: torrentleech: working on: TL-0day MAR13-2014
# [2015-04-24 12:22:36.742000] DEBUG: torrentleech: working on: Video2Brain Windows 8 1 Tipps Tricks Troubleshooting GERMAN-EMERGE
# [2015-04-24 12:22:36.746000] DEBUG: torrentleech: working on: PLURALSIGHT WINDOWS 8 1 NEW FEATURES FOR C SHARP XAML DEVELOPERS TUTORIAL-kEISO
# [2015-04-24 12:22:36.748000] DEBUG: torrentleech: working on: TL-0day FEB27-2014
# [2015-04-24 12:22:36.750000] DEBUG: torrentleech: working on: WINDOWS 8 1 2014 UPDATE X86 ONLY MSU 9600 16610 140201-1007-WZT
# [2015-04-24 12:22:36.753000] DEBUG: torrentleech: working on: WINDOWS 8 1 2014 UPDATE X64 ONLY MSU 9600 16610 140201-1007-WZT
# [2015-04-24 12:22:36.756000] DEBUG: torrentleech: working on: TL-0day JAN29-2014
# [2015-04-24 12:22:36.759000] DEBUG: torrentleech: working on: EBOOKS WEEK04 2014-TL
# [2015-04-24 12:22:36.761000] DEBUG: torrentleech: working on: EBOOKS WEEK03 2014-TL
# [2015-04-24 12:22:36.763000] DEBUG: torrentleech: working on: TL-0day JAN20-2014
# [2015-04-24 12:22:36.765000] DEBUG: torrentleech: working on: Rust Alpha Version 12-19-2013
# [2015-04-24 12:22:36.767000] DEBUG: torrentleech: working on: Windows 8 1 AIO 20in1 x86 x64 en-US Pre-Activated DaRT 8 1 Jan2014
# [2015-04-24 12:22:36.770000] DEBUG: torrentleech: working on: TL-0day JAN08-2014
# [2015-04-24 12:22:36.772000] DEBUG: torrentleech: working on: TL-0day DEC18-2013
# [2015-04-24 12:22:36.775000] DEBUG: torrentleech: working on: MICROSOFT WINDOWS 8 1 RTM X86 DUTCH DVD-WZT
# [2015-04-24 12:22:36.777000] DEBUG: torrentleech: working on: MICROSOFT WINDOWS 8 1 RTM X64 DUTCH DVD-WZT
# [2015-04-24 12:22:36.779000] DEBUG: torrentleech: working on: EBOOKS PK WK49-TL
# [2015-04-24 12:22:36.781000] DEBUG: torrentleech: Successfully processed 100 results

# %%
r
# Out:
# [{'id': u'601550',
#   'leechers': 6,
#   'name': u'Windows 8 1 8in1 x64 en-US Apr2015',
#   'seeders': 89,
#   'size': u'6.18 GB',
#   'url': u'/download/601550/Windows.8.1.8in1.x64.en-US.Apr2015.torrent'},
#  {'id': u'600511',
#   'leechers': 41,
#   'name': u'TL-0day APR11 APR12 APR13-2015',
#   'seeders': 20,
#   'size': u'21.11 GB',
#   'url': u'/download/600511/TL-0day.APR11.APR12.APR13-2015.torrent'},
#  {'id': u'589986',
#   'leechers': 19,
#   'name': u'TL-0day MAR05-2015',
#   'seeders': 13,
#   'size': u'4.73 GB',
#   'url': u'/download/589986/TL-0day.MAR05-2015.torrent'},
#  {'id': u'588245',
#   'leechers': 46,
#   'name': u'TL-0day MAR03-2015',
#   'seeders': 21,
#   'size': u'1.42 GB',
#   'url': u'/download/588245/TL-0day.MAR03-2015.torrent'},
#  {'id': u'587932',
#   'leechers': 39,
#   'name': u'EBOOKS WEEK09 2015-TL',
#   'seeders': 34,
#   'size': u'4.8 GB',
#   'url': u'/download/587932/EBOOKS.WEEK09.2015-TL.torrent'},
#  {'id': u'585976',
#   'leechers': 0,
#   'name': u'LYNDA UP AND RUNNING WITH WINDOWS 8 1 PHONES TUTORIAL-kEISO',
#   'seeders': 3,
#   'size': u'270 MB',
#   'url': u'/download/585976/LYNDA.UP.AND.RUNNING.WITH.WINDOWS.8.1.PHONES.TUTORIAL-kEISO.torrent'},
#  {'id': u'582023',
#   'leechers': 2,
#   'name': u'Windows 8 1 8in1 x86 en-US Feb2015',
#   'seeders': 49,
#   'size': u'4.27 GB',
#   'url': u'/download/582023/Windows.8.1.8in1.x86.en-US.Feb2015.torrent'},
#  {'id': u'582022',
#   'leechers': 10,
#   'name': u'Windows 8 1 8in1 x64 en-US Feb2015',
#   'seeders': 221,
#   'size': u'6.06 GB',
#   'url': u'/download/582022/Windows.8.1.8in1.x64.en-US.Feb2015.torrent'},
#  {'id': u'581885',
#   'leechers': 22,
#   'name': u'TL-0day FEB11-2015',
#   'seeders': 10,
#   'size': u'1.79 GB',
#   'url': u'/download/581885/TL-0day.FEB11-2015.torrent'},
#  {'id': u'578757',
#   'leechers': 29,
#   'name': u'TL-0day JAN31-2015',
#   'seeders': 12,
#   'size': u'4.44 GB',
#   'url': u'/download/578757/TL-0day.JAN31-2015.torrent'},
#  {'id': u'577738',
#   'leechers': 1,
#   'name': u'Windows SuperAIO v6 110-in-1 en-US DaRT7-8 1 - murphy78',
#   'seeders': 17,
#   'size': u'24.02 GB',
#   'url': u'/download/577738/Windows.SuperAIO.v6.110-in-1.en-US.DaRT7-8.1.-.murphy78.torrent'},
#  {'id': u'576218',
#   'leechers': 0,
#   'name': u'Windows 8 1 AIO 54in1 with Update x86 en-US Dec2014 FINAL v2',
#   'seeders': 14,
#   'size': u'6.52 GB',
#   'url': u'/download/576218/Windows.8.1.AIO.54in1.with.Update.x86.en-US.Dec2014.FINAL.v2.torrent'},
#  {'id': u'576217',
#   'leechers': 0,
#   'name': u'Windows 8 1 AIO 54in1 with Update x64 en-US Dec2014 FINAL v2',
#   'seeders': 38,
#   'size': u'9.9 GB',
#   'url': u'/download/576217/Windows.8.1.AIO.54in1.with.Update.x64.en-US.Dec2014.FINAL.v2.torrent'},
#  {'id': u'576216',
#   'leechers': 2,
#   'name': u'Windows 8 1 8in1 x86 en-US Jan2015',
#   'seeders': 22,
#   'size': u'4.21 GB',
#   'url': u'/download/576216/Windows.8.1.8in1.x86.en-US.Jan2015.torrent'},
#  {'id': u'576215',
#   'leechers': 1,
#   'name': u'Windows 8 1 8in1 x64 en-US Jan2015',
#   'seeders': 67,
#   'size': u'6 GB',
#   'url': u'/download/576215/Windows.8.1.8in1.x64.en-US.Jan2015.torrent'},
#  {'id': u'576071',
#   'leechers': 50,
#   'name': u'TL-0day JAN21-2015',
#   'seeders': 7,
#   'size': u'11.59 GB',
#   'url': u'/download/576071/TL-0day.JAN21-2015.torrent'},
#  {'id': u'574238',
#   'leechers': 36,
#   'name': u'EBOOKS WEEK02 2015-TL',
#   'seeders': 30,
#   'size': u'2.04 GB',
#   'url': u'/download/574238/EBOOKS.WEEK02.2015-TL.torrent'},
#  {'id': u'572204',
#   'leechers': 0,
#   'name': u'Windows 8 1 AIO 54in1 with Update x86 en-US Dec2014',
#   'seeders': 18,
#   'size': u'6.56 GB',
#   'url': u'/download/572204/Windows.8.1.AIO.54in1.with.Update.x86.en-US.Dec2014.torrent'},
#  {'id': u'572203',
#   'leechers': 0,
#   'name': u'Windows 8 1 AIO 54in1 with Update x64 en-US Dec2014',
#   'seeders': 40,
#   'size': u'9.95 GB',
#   'url': u'/download/572203/Windows.8.1.AIO.54in1.with.Update.x64.en-US.Dec2014.torrent'},
#  {'id': u'569019',
#   'leechers': 72,
#   'name': u'TL-0day DEC24-2014',
#   'seeders': 9,
#   'size': u'14.87 GB',
#   'url': u'/download/569019/TL-0day.DEC24-2014.torrent'},
#  {'id': u'568843',
#   'leechers': 37,
#   'name': u'TL-0day DEC22-2014',
#   'seeders': 8,
#   'size': u'10.67 GB',
#   'url': u'/download/568843/TL-0day.DEC22-2014.torrent'},
#  {'id': u'561918',
#   'leechers': 63,
#   'name': u'TL-0day NOV23-2014',
#   'seeders': 11,
#   'size': u'25.61 GB',
#   'url': u'/download/561918/TL-0day.NOV23-2014.torrent'},
#  {'id': u'561915',
#   'leechers': 66,
#   'name': u'TL-0day NOV22-2014',
#   'seeders': 6,
#   'size': u'32 GB',
#   'url': u'/download/561915/TL-0day.NOV22-2014.torrent'},
#  {'id': u'557863',
#   'leechers': 0,
#   'name': u'Video2Brain Hyper V auf Windows 8 1 Grundlagen GERMAN-LiQUiDWARE',
#   'seeders': 0,
#   'size': u'296 MB',
#   'url': u'/download/557863/Video2Brain.Hyper.V.auf.Windows.8.1.Grundlagen.GERMAN-LiQUiDWARE.torrent'},
#  {'id': u'557770',
#   'leechers': 32,
#   'name': u'TL-0day NOV06-2014',
#   'seeders': 4,
#   'size': u'15.8 GB',
#   'url': u'/download/557770/TL-0day.NOV06-2014.torrent'},
#  {'id': u'554961',
#   'leechers': 0,
#   'name': u'Windows 8 1 AIO 48in1 with Update x86 en-US Oct2014',
#   'seeders': 25,
#   'size': u'4.82 GB',
#   'url': u'/download/554961/Windows.8.1.AIO.48in1.with.Update.x86.en-US.Oct2014.torrent'},
#  {'id': u'554848',
#   'leechers': 3,
#   'name': u'Windows 8 1 AIO 48in1 with Update x64 en-US Oct2014',
#   'seeders': 134,
#   'size': u'6.72 GB',
#   'url': u'/download/554848/Windows.8.1.AIO.48in1.with.Update.x64.en-US.Oct2014.torrent'},
#  {'id': u'542272',
#   'leechers': 12,
#   'name': u'TL-0day SEP12-2014',
#   'seeders': 3,
#   'size': u'10.12 GB',
#   'url': u'/download/542272/TL-0day.SEP12-2014.torrent'},
#  {'id': u'540763',
#   'leechers': 0,
#   'name': u'Windows 8 1 Dark V11 6',
#   'seeders': 9,
#   'size': u'3.99 GB',
#   'url': u'/download/540763/Windows.8.1.Dark.V11.6.torrent'},
#  {'id': u'533160',
#   'leechers': 1,
#   'name': u'Windows 8 1 AIO 24in1 with Update x86 en-US Jul2014',
#   'seeders': 17,
#   'size': u'4.16 GB',
#   'url': u'/download/533160/Windows.8.1.AIO.24in1.with.Update.x86.en-US.Jul2014.torrent'},
#  {'id': u'533157',
#   'leechers': 0,
#   'name': u'Windows 8 1 AIO 24in1 with Update x64 en-US Jul2014',
#   'seeders': 94,
#   'size': u'5.69 GB',
#   'url': u'/download/533157/Windows.8.1.AIO.24in1.with.Update.x64.en-US.Jul2014.torrent'},
#  {'id': u'532077',
#   'leechers': 0,
#   'name': u'LYNDA WINDOWS 8 1 TIPS AND TRICKS TUTORIAL-kEISO',
#   'seeders': 6,
#   'size': u'260 MB',
#   'url': u'/download/532077/LYNDA.WINDOWS.8.1.TIPS.AND.TRICKS.TUTORIAL-kEISO.torrent'},
#  {'id': u'529412',
#   'leechers': 0,
#   'name': u'CBT NUGGETS MICROSOFT MCSA WINDOWS 8 1 70 687 CONFIGURING WINDOWS 8 1 TUTORIAL-kEISO',
#   'seeders': 15,
#   'size': u'1.92 GB',
#   'url': u'/download/529412/CBT.NUGGETS.MICROSOFT.MCSA.WINDOWS.8.1.70.687.CONFIGURING.WINDOWS.8.1.TUTORIAL-kEISO.torrent'},
#  {'id': u'528980',
#   'leechers': 0,
#   'name': u'Microsoft Windows Embedded 8 1 Industry Enterprise x64 GERMAN-NEWiSO',
#   'seeders': 0,
#   'size': u'3.31 GB',
#   'url': u'/download/528980/Microsoft.Windows.Embedded.8.1.Industry.Enterprise.x64.GERMAN-NEWiSO.torrent'},
#  {'id': u'528978',
#   'leechers': 0,
#   'name': u'Microsoft Windows Embedded 8 1 Industry Enterprise x64-NEWiSO',
#   'seeders': 9,
#   'size': u'3.28 GB',
#   'url': u'/download/528978/Microsoft.Windows.Embedded.8.1.Industry.Enterprise.x64-NEWiSO.torrent'},
#  {'id': u'528977',
#   'leechers': 0,
#   'name': u'Microsoft Windows Embedded 8 1 Industry Enterprise x86 GERMAN-NEWiSO',
#   'seeders': 0,
#   'size': u'2.43 GB',
#   'url': u'/download/528977/Microsoft.Windows.Embedded.8.1.Industry.Enterprise.x86.GERMAN-NEWiSO.torrent'},
#  {'id': u'528974',
#   'leechers': 0,
#   'name': u'Microsoft Windows Embedded 8 1 Industry Enterprise x86-NEWiSO',
#   'seeders': 3,
#   'size': u'2.42 GB',
#   'url': u'/download/528974/Microsoft.Windows.Embedded.8.1.Industry.Enterprise.x86-NEWiSO.torrent'},
#  {'id': u'528971',
#   'leechers': 0,
#   'name': u'Microsoft Windows Embedded 8 1 Industry Pro x64 GERMAN-NEWiSO',
#   'seeders': 0,
#   'size': u'3.3 GB',
#   'url': u'/download/528971/Microsoft.Windows.Embedded.8.1.Industry.Pro.x64.GERMAN-NEWiSO.torrent'},
#  {'id': u'528970',
#   'leechers': 0,
#   'name': u'Microsoft Windows Embedded 8 1 Industry Pro x64-NEWiSO',
#   'seeders': 14,
#   'size': u'3.28 GB',
#   'url': u'/download/528970/Microsoft.Windows.Embedded.8.1.Industry.Pro.x64-NEWiSO.torrent'},
#  {'id': u'528968',
#   'leechers': 0,
#   'name': u'Microsoft Windows Embedded 8 1 Industry Pro x86 GERMAN-NEWiSO',
#   'seeders': 0,
#   'size': u'2.43 GB',
#   'url': u'/download/528968/Microsoft.Windows.Embedded.8.1.Industry.Pro.x86.GERMAN-NEWiSO.torrent'},
#  {'id': u'528967',
#   'leechers': 0,
#   'name': u'Microsoft Windows Embedded 8 1 Industry Pro x86-NEWiSO',
#   'seeders': 5,
#   'size': u'2.42 GB',
#   'url': u'/download/528967/Microsoft.Windows.Embedded.8.1.Industry.Pro.x86-NEWiSO.torrent'},
#  {'id': u'524472',
#   'leechers': 27,
#   'name': u'EBOOKS WEEK25 2014-TL',
#   'seeders': 27,
#   'size': u'3.07 GB',
#   'url': u'/download/524472/EBOOKS.WEEK25.2014-TL.torrent'},
#  {'id': u'523010',
#   'leechers': 91,
#   'name': u'VTC Complete pack',
#   'seeders': 8,
#   'size': u'628.71 GB',
#   'url': u'/download/523010/VTC.Complete.pack.torrent'},
#  {'id': u'521722',
#   'leechers': 0,
#   'name': u'Windows 8 1 AIO 24in1 with Update x86 en-US Jun2014',
#   'seeders': 8,
#   'size': u'3.15 GB',
#   'url': u'/download/521722/Windows.8.1.AIO.24in1.with.Update.x86.en-US.Jun2014.torrent'},
#  {'id': u'521718',
#   'leechers': 0,
#   'name': u'Windows 8 1 AIO 24in1 with Update x64 en-US Jun2014',
#   'seeders': 58,
#   'size': u'4.08 GB',
#   'url': u'/download/521718/Windows.8.1.AIO.24in1.with.Update.x64.en-US.Jun2014.torrent'},
#  {'id': u'521694',
#   'leechers': 2,
#   'name': u'Windows 8 1 Enterprise with Update (x64) - MultiLang',
#   'seeders': 8,
#   'size': u'8.74 GB',
#   'url': u'/download/521694/Windows.8.1.Enterprise.with.Update.(x64).-.MultiLang.torrent'},
#  {'id': u'520753',
#   'leechers': 0,
#   'name': u'Windows 8 1 with Update & Crack x86 pt-BR Mar2014 MSDN',
#   'seeders': 6,
#   'size': u'3.61 GB',
#   'url': u'/download/520753/Windows.8.1.with.Update.&.Crack.x86.pt-BR.Mar2014.MSDN.torrent'},
#  {'id': u'520752',
#   'leechers': 0,
#   'name': u'Windows 8 1 with Updates & Crack x64 pt-BR Mar2014 MSDN',
#   'seeders': 14,
#   'size': u'5.35 GB',
#   'url': u'/download/520752/Windows.8.1.with.Updates.&.Crack.x64.pt-BR.Mar2014.MSDN.torrent'},
#  {'id': u'519608',
#   'leechers': 31,
#   'name': u'Extreme Android Pack-TL',
#   'seeders': 13,
#   'size': u'22.48 GB',
#   'url': u'/download/519608/Extreme.Android.Pack-TL.torrent'},
#  {'id': u'519457',
#   'leechers': 27,
#   'name': u'Ebooks Pack-TL',
#   'seeders': 8,
#   'size': u'13.44 GB',
#   'url': u'/download/519457/Ebooks.Pack-TL.torrent'},
#  {'id': u'518876',
#   'leechers': 32,
#   'name': u'TL-0day JUN01-2014',
#   'seeders': 2,
#   'size': u'26.16 GB',
#   'url': u'/download/518876/TL-0day.JUN01-2014.torrent'},
#  {'id': u'518874',
#   'leechers': 38,
#   'name': u'EBOOKS WEEK22 2014-TL',
#   'seeders': 19,
#   'size': u'3.74 GB',
#   'url': u'/download/518874/EBOOKS.WEEK22.2014-TL.torrent'},
#  {'id': u'517272',
#   'leechers': 0,
#   'name': u'Windows 8 1 AIO 20in1 with Update x64 en-US May2014',
#   'seeders': 23,
#   'size': u'3.92 GB',
#   'url': u'/download/517272/Windows.8.1.AIO.20in1.with.Update.x64.en-US.May2014.torrent'},
#  {'id': u'517271',
#   'leechers': 0,
#   'name': u'Windows 8 1 AIO 20in1 with Update x86 en-US May2014',
#   'seeders': 3,
#   'size': u'3.03 GB',
#   'url': u'/download/517271/Windows.8.1.AIO.20in1.with.Update.x86.en-US.May2014.torrent'},
#  {'id': u'517077',
#   'leechers': 0,
#   'name': u'Video2Brain Windows 8 1 fuer Profis UPDATE 05 2014 GERMAN-EMERGE',
#   'seeders': 0,
#   'size': u'439 MB',
#   'url': u'/download/517077/Video2Brain.Windows.8.1.fuer.Profis.UPDATE.05.2014.GERMAN-EMERGE.torrent'},
#  {'id': u'516797',
#   'leechers': 27,
#   'name': u'TL-0day MAY23-2014',
#   'seeders': 4,
#   'size': u'16.66 GB',
#   'url': u'/download/516797/TL-0day.MAY23-2014.torrent'},
#  {'id': u'516028',
#   'leechers': 12,
#   'name': u'TL-0day MAY21-2014',
#   'seeders': 3,
#   'size': u'12.89 GB',
#   'url': u'/download/516028/TL-0day.MAY21-2014.torrent'},
#  {'id': u'515544',
#   'leechers': 0,
#   'name': u'Video2Brain Windows v8 1 Tipps Tricks Troubleshooting Update04 2014 GERMAN-SHooTERS',
#   'seeders': 1,
#   'size': u'413 MB',
#   'url': u'/download/515544/Video2Brain.Windows.v8.1.Tipps.Tricks.Troubleshooting.Update04.2014.GERMAN-SHooTERS.torrent'},
#  {'id': u'515459',
#   'leechers': 3,
#   'name': u'TL-0day MAY19-2014',
#   'seeders': 2,
#   'size': u'2.95 GB',
#   'url': u'/download/515459/TL-0day.MAY19-2014.torrent'},
#  {'id': u'515204',
#   'leechers': 19,
#   'name': u'EBOOKS WEEK20 2014-TL',
#   'seeders': 11,
#   'size': u'3.72 GB',
#   'url': u'/download/515204/EBOOKS.WEEK20.2014-TL.torrent'},
#  {'id': u'513505',
#   'leechers': 0,
#   'name': u'PLURALSIGHT DEPLOYING WINDOWS 8 1 AND WINDOWS SERVER 2012 R2 USING MDT 2013 TUTORIAL-kEISO',
#   'seeders': 6,
#   'size': u'571 MB',
#   'url': u'/download/513505/PLURALSIGHT.DEPLOYING.WINDOWS.8.1.AND.WINDOWS.SERVER.2012.R2.USING.MDT.2013.TUTORIAL-kEISO.torrent'},
#  {'id': u'511458',
#   'leechers': 1,
#   'name': u'Telerik 2014 Q1 Pack-TL',
#   'seeders': 15,
#   'size': u'786 MB',
#   'url': u'/download/511458/Telerik.2014.Q1.Pack-TL.torrent'},
#  {'id': u'508269',
#   'leechers': 11,
#   'name': u'EBOOKS WEEK16 2014-TL',
#   'seeders': 11,
#   'size': u'1.73 GB',
#   'url': u'/download/508269/EBOOKS.WEEK16.2014-TL.torrent'},
#  {'id': u'507935',
#   'leechers': 1,
#   'name': u'Windows 8 1 AIO 20in1 with Update x64 en-US April 2014 v2',
#   'seeders': 29,
#   'size': u'3.7 GB',
#   'url': u'/download/507935/Windows.8.1.AIO.20in1.with.Update.x64.en-US.April.2014.v2.torrent'},
#  {'id': u'507934',
#   'leechers': 0,
#   'name': u'Windows 8 1 AIO 20in1 with Update x86 en-US April 2014 v2',
#   'seeders': 2,
#   'size': u'2.87 GB',
#   'url': u'/download/507934/Windows.8.1.AIO.20in1.with.Update.x86.en-US.April.2014.v2.torrent'},
#  {'id': u'505503',
#   'leechers': 0,
#   'name': u'LYNDA WINDOWS 8 1 UPDATE 1 FIRST LOOK TUTORIAL-kEISO',
#   'seeders': 2,
#   'size': u'10 MB',
#   'url': u'/download/505503/LYNDA.WINDOWS.8.1.UPDATE.1.FIRST.LOOK.TUTORIAL-kEISO.torrent'},
#  {'id': u'505378',
#   'leechers': 29,
#   'name': u'EBOOKS WEEK14 2014-TL',
#   'seeders': 22,
#   'size': u'4.64 GB',
#   'url': u'/download/505378/EBOOKS.WEEK14.2014-TL.torrent'},
#  {'id': u'504844',
#   'leechers': 0,
#   'name': u'Windows Embedded 8 1 Industry Pro with Update (x64) - DVD (English)',
#   'seeders': 7,
#   'size': u'3.51 GB',
#   'url': u'/download/504844/Windows.Embedded.8.1.Industry.Pro.with.Update.(x64).-.DVD.(English).torrent'},
#  {'id': u'504843',
#   'leechers': 0,
#   'name': u'Windows Embedded 8 1 Industry Pro with Update (x86) - DVD (English)',
#   'seeders': 2,
#   'size': u'2.57 GB',
#   'url': u'/download/504843/Windows.Embedded.8.1.Industry.Pro.with.Update.(x86).-.DVD.(English).torrent'},
#  {'id': u'504842',
#   'leechers': 0,
#   'name': u'Windows Embedded 8 1 Industry Enterprise with Update (x64) - DVD (English)',
#   'seeders': 2,
#   'size': u'3.51 GB',
#   'url': u'/download/504842/Windows.Embedded.8.1.Industry.Enterprise.with.Update.(x64).-.DVD.(English).torrent'},
#  {'id': u'504840',
#   'leechers': 0,
#   'name': u'Windows Embedded 8 1 Industry Enterprise with Update (x86) - DVD (English)',
#   'seeders': 1,
#   'size': u'2.58 GB',
#   'url': u'/download/504840/Windows.Embedded.8.1.Industry.Enterprise.with.Update.(x86).-.DVD.(English).torrent'},
#  {'id': u'504768',
#   'leechers': 0,
#   'name': u'Windows 8 1 Professional VL with Update (x64) - DVD (English)',
#   'seeders': 50,
#   'size': u'3.69 GB',
#   'url': u'/download/504768/Windows.8.1.Professional.VL.with.Update.(x64).-.DVD.(English).torrent'},
#  {'id': u'504767',
#   'leechers': 0,
#   'name': u'Windows 8 1 Professional VL with Update (x86) - DVD (English)',
#   'seeders': 5,
#   'size': u'2.75 GB',
#   'url': u'/download/504767/Windows.8.1.Professional.VL.with.Update.(x86).-.DVD.(English).torrent'},
#  {'id': u'504766',
#   'leechers': 0,
#   'name': u'Windows 8 1 Enterprise N with Update (x64) - DVD (English)',
#   'seeders': 2,
#   'size': u'3.53 GB',
#   'url': u'/download/504766/Windows.8.1.Enterprise.N.with.Update.(x64).-.DVD.(English).torrent'},
#  {'id': u'504765',
#   'leechers': 0,
#   'name': u'Windows 8 1 Enterprise N with Update (x86) - DVD (English)',
#   'seeders': 1,
#   'size': u'2.62 GB',
#   'url': u'/download/504765/Windows.8.1.Enterprise.N.with.Update.(x86).-.DVD.(English).torrent'},
#  {'id': u'504764',
#   'leechers': 0,
#   'name': u'Windows 8 1 N with Update (multiple editions) (x64) - DVD (English)',
#   'seeders': 0,
#   'size': u'3.62 GB',
#   'url': u'/download/504764/Windows.8.1.N.with.Update.(multiple.editions).(x64).-.DVD.(English).torrent'},
#  {'id': u'504763',
#   'leechers': 0,
#   'name': u'Windows 8 1 N with Update (multiple editions) (x86) - DVD (English)',
#   'seeders': 0,
#   'size': u'2.7 GB',
#   'url': u'/download/504763/Windows.8.1.N.with.Update.(multiple.editions).(x86).-.DVD.(English).torrent'},
#  {'id': u'504641',
#   'leechers': 0,
#   'name': u'Windows 8 1 Enterprise with Update (x64) - DVD (English)',
#   'seeders': 10,
#   'size': u'3.68 GB',
#   'url': u'/download/504641/Windows.8.1.Enterprise.with.Update.(x64).-.DVD.(English).torrent'},
#  {'id': u'504640',
#   'leechers': 0,
#   'name': u'Windows 8 1 Enterprise with Update (x86) - DVD (English)',
#   'seeders': 3,
#   'size': u'2.74 GB',
#   'url': u'/download/504640/Windows.8.1.Enterprise.with.Update.(x86).-.DVD.(English).torrent'},
#  {'id': u'504639',
#   'leechers': 0,
#   'name': u'Windows 8 1 with Update (multiple editions) (x64) - DVD (English)',
#   'seeders': 15,
#   'size': u'3.83 GB',
#   'url': u'/download/504639/Windows.8.1.with.Update.(multiple.editions).(x64).-.DVD.(English).torrent'},
#  {'id': u'504638',
#   'leechers': 0,
#   'name': u'Windows 8 1 with Update (multiple editions) (x86) - DVD (English)',
#   'seeders': 3,
#   'size': u'2.86 GB',
#   'url': u'/download/504638/Windows.8.1.with.Update.(multiple.editions).(x86).-.DVD.(English).torrent'},
#  {'id': u'500479',
#   'leechers': 0,
#   'name': u'Windows 8 1 AIO S14 x86 en-US DaRT 8 1 Pre-Activated Mar2014',
#   'seeders': 4,
#   'size': u'3 GB',
#   'url': u'/download/500479/Windows.8.1.AIO.S14.x86.en-US.DaRT.8.1.Pre-Activated.Mar2014.torrent'},
#  {'id': u'500478',
#   'leechers': 0,
#   'name': u'Windows 8 1 AIO S14 x64 en-US DaRT 8 1 Pre-Activated Mar2014',
#   'seeders': 32,
#   'size': u'3.94 GB',
#   'url': u'/download/500478/Windows.8.1.AIO.S14.x64.en-US.DaRT.8.1.Pre-Activated.Mar2014.torrent'},
#  {'id': u'499809',
#   'leechers': 9,
#   'name': u'TL-0day MAR13-2014',
#   'seeders': 3,
#   'size': u'10.67 GB',
#   'url': u'/download/499809/TL-0day.MAR13-2014.torrent'},
#  {'id': u'497438',
#   'leechers': 1,
#   'name': u'Video2Brain Windows 8 1 Tipps Tricks Troubleshooting GERMAN-EMERGE',
#   'seeders': 0,
#   'size': u'376 MB',
#   'url': u'/download/497438/Video2Brain.Windows.8.1.Tipps.Tricks.Troubleshooting.GERMAN-EMERGE.torrent'},
#  {'id': u'496758',
#   'leechers': 0,
#   'name': u'PLURALSIGHT WINDOWS 8 1 NEW FEATURES FOR C SHARP XAML DEVELOPERS TUTORIAL-kEISO',
#   'seeders': 3,
#   'size': u'686 MB',
#   'url': u'/download/496758/PLURALSIGHT.WINDOWS.8.1.NEW.FEATURES.FOR.C.SHARP.XAML.DEVELOPERS.TUTORIAL-kEISO.torrent'},
#  {'id': u'496315',
#   'leechers': 3,
#   'name': u'TL-0day FEB27-2014',
#   'seeders': 2,
#   'size': u'10.71 GB',
#   'url': u'/download/496315/TL-0day.FEB27-2014.torrent'},
#  {'id': u'491951',
#   'leechers': 0,
#   'name': u'WINDOWS 8 1 2014 UPDATE X86 ONLY MSU 9600 16610 140201-1007-WZT',
#   'seeders': 2,
#   'size': u'258 MB',
#   'url': u'/download/491951/WINDOWS.8.1.2014.UPDATE.X86.ONLY.MSU.9600.16610.140201-1007-WZT.torrent'},
#  {'id': u'491950',
#   'leechers': 0,
#   'name': u'WINDOWS 8 1 2014 UPDATE X64 ONLY MSU 9600 16610 140201-1007-WZT ',
#   'seeders': 5,
#   'size': u'572 MB',
#   'url': u'/download/491950/WINDOWS.8.1.2014.UPDATE.X64.ONLY.MSU.9600.16610.140201-1007-WZT..torrent'},
#  {'id': u'489947',
#   'leechers': 7,
#   'name': u'TL-0day JAN29-2014',
#   'seeders': 2,
#   'size': u'2.29 GB',
#   'url': u'/download/489947/TL-0day.JAN29-2014.torrent'},
#  {'id': u'489444',
#   'leechers': 15,
#   'name': u'EBOOKS WEEK04 2014-TL',
#   'seeders': 11,
#   'size': u'3.06 GB',
#   'url': u'/download/489444/EBOOKS.WEEK04.2014-TL.torrent'},
#  {'id': u'487840',
#   'leechers': 15,
#   'name': u'EBOOKS WEEK03 2014-TL',
#   'seeders': 13,
#   'size': u'4.26 GB',
#   'url': u'/download/487840/EBOOKS.WEEK03.2014-TL.torrent'},
#  {'id': u'487838',
#   'leechers': 24,
#   'name': u'TL-0day JAN20-2014',
#   'seeders': 5,
#   'size': u'9.49 GB',
#   'url': u'/download/487838/TL-0day.JAN20-2014.torrent'},
#  {'id': u'487461',
#   'leechers': 0,
#   'name': u'Rust Alpha Version 12-19-2013',
#   'seeders': 3,
#   'size': u'849 MB',
#   'url': u'/download/487461/Rust.Alpha.Version.12-19-2013.torrent'},
#  {'id': u'486703',
#   'leechers': 13,
#   'name': u'Windows 8 1 AIO 20in1 x86 x64 en-US Pre-Activated DaRT 8 1 Jan2014',
#   'seeders': 32,
#   'size': u'6.87 GB',
#   'url': u'/download/486703/Windows.8.1.AIO.20in1.x86.x64.en-US.Pre-Activated.DaRT.8.1.Jan2014.torrent'},
#  {'id': u'485074',
#   'leechers': 12,
#   'name': u'TL-0day JAN08-2014',
#   'seeders': 2,
#   'size': u'1.93 GB',
#   'url': u'/download/485074/TL-0day.JAN08-2014.torrent'},
#  {'id': u'481408',
#   'leechers': 6,
#   'name': u'TL-0day DEC18-2013',
#   'seeders': 2,
#   'size': u'8.25 GB',
#   'url': u'/download/481408/TL-0day.DEC18-2013.torrent'},
#  {'id': u'480980',
#   'leechers': 0,
#   'name': u'MICROSOFT WINDOWS 8 1 RTM X86 DUTCH DVD-WZT',
#   'seeders': 1,
#   'size': u'2.68 GB',
#   'url': u'/download/480980/MICROSOFT.WINDOWS.8.1.RTM.X86.DUTCH.DVD-WZT.torrent'},
#  {'id': u'480977',
#   'leechers': 0,
#   'name': u'MICROSOFT WINDOWS 8 1 RTM X64 DUTCH DVD-WZT',
#   'seeders': 0,
#   'size': u'3.61 GB',
#   'url': u'/download/480977/MICROSOFT.WINDOWS.8.1.RTM.X64.DUTCH.DVD-WZT.torrent'},
#  {'id': u'480793',
#   'leechers': 7,
#   'name': u'EBOOKS PK WK49-TL',
#   'seeders': 7,
#   'size': u'3.2 GB',
#   'url': u'/download/480793/EBOOKS.PK.WK49-TL.torrent'}]

# %%
r
# Out:
# []

# %%
# %pdb
# Out:
# Automatic pdb calling has been turned ON

# %%
match
